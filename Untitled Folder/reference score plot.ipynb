# %%
import matplotlib.pyplot as plt

# %%
y_1 = [
    9.3e-3,
5.1e-3,
3.1e-3,
2.3e-3,
1.7e-3,
9.7e-4,
3.9e-4,
1.9e-4,
1.0e-4,
    
]
y_2 = [
   
2.0e-3,
1.8e-3,
1.5e-3,
1.3e-3,
1.2e-3,
8.3e-4,
4.8e-4,
3.1e-4,
2.6e-4,
]

x = [
    1,
    2,
    3,
    4,
    5,
    10,
    25,
    50,
    100
]

# %%
plt.plot(x, y_1, '--', label="m-MC estimate")
plt.plot(x, y_2, '--', label="predictive model with m reference utilities")

plt.xlabel('m references')
plt.ylabel('mean squared error')

plt.yscale('log')
plt.legend()
plt.show()
